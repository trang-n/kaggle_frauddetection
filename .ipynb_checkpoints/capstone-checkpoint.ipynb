# %% [markdown]
# ## Load libraries

# %%
#importing libraries
import numpy as np 
import pandas as pd #for data processing
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from sklearn import preprocessing
import warnings
warnings.filterwarnings('ignore')

#plotly import
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.tools as tls

# %%
from sklearn.model_selection import KFold, TimeSeriesSplit
from sklearn.metrics import roc_auc_score
from sklearn import preprocessing
from xgboost import plot_importance
from sklearn.metrics import make_scorer
from xgboost import XGBClassifier
import xgboost as xgb

# %%
#load data
train_identity = pd.read_csv('data/train_identity.csv', index_col='TransactionID')
train_transaction = pd.read_csv('data/train_transaction.csv', index_col='TransactionID')
test_identity = pd.read_csv('data/test_identity.csv', index_col='TransactionID')
test_transaction = pd.read_csv('data/test_transaction.csv', index_col='TransactionID')
sample_sub = pd.read_csv('data/sample_submission.csv', index_col='TransactionID')

# %%
# Function to reduce the DF size
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
train_transaction = reduce_mem_usage(train_transaction)
test_transaction = reduce_mem_usage(test_transaction)
# Out:
# Mem. usage decreased to 564.60 Mb (68.5% reduction)
# Mem. usage decreased to 494.52 Mb (67.9% reduction)

# %%
#combine into train and test dataset
train = train_transaction.merge(train_identity, how='left', left_index=True, right_index=True)
test = test_transaction.merge(test_identity, how='left', left_index=True, right_index=True)

#left join identity to transaction because there are more rows in transaction

# %% [markdown]
# ## Baseline Model

# %%
# y_train = train['isFraud'].copy()

# #drop target and fill NAs
# X_train = train.drop('isFraud', axis = 1)
# X_test = test.copy()
# X_train = X_train.fillna(-999)
# X_test = X_test.fillna(-999)

# %%
# ##Label Encoding

# for f in X_train.columns:
#     if X_train[f].dtype == 'object' or X_test[f].dtype == 'object':
#         lbl = preprocessing.LabelEncoder()
#         lbl.fit(list(X_train[f].values) + list(X_test[f].values))
#         X_train[f] = lbl.transform(list(X_train[f].values))
#         X_test[f] = lbl.transform(list(X_test[f].values))

# %%
# clf = xgb.XGBClassifier(n_estimators = 500, 
#                        n_jobs = 4, 
#                        max_depth = 9, 
#                        learning_rate = 0.05, 
#                        sub_sample = 0.9, 
#                        colsample_bytree = 0.9, 
#                        missing = -999)
# clf.fit(X_train, y_train)

# %%
# sample_sub['isFraud'] = clf.predict_proba(X_test)[:,1]
# sample_sub.to_csv('xgboost.csv') #score: 0.9347

# %% [markdown]
# ## Data Exploration

# %%
#functions to explore the data - rows, cols, misisng values
def summarize(df):
    print(f"Dataset Shape: {df.shape}") #cols and rows
    summary = pd.DataFrame(df.dtypes, columns = ['dtypes'])
    summary = summary.reset_index() #add index column
    summary['Name']  = summary['index'] #create name column like the index
    summary = summary[['Name', 'dtypes']] #remove 'index' column
    summary['Missing'] = (round(((df.isnull().sum() / len(df)) *100),2)).values #create column of null values count
    summary['First Value'] = df.loc[0].values
    summary['Second Value'] = df.loc[1].values
    summary['Third Value'] = df.loc[2].values

    return summary


def CalcOutliers(df):
    #calculating mean and std of the array
    data_mean, data_std = np.mean(df), np.std(df)
    
    #setting the cut line to both higher and lower values
    cut = data_std *3
    
    #Calculating the higher and lower cut values
    lower, upper = data_mean -cut, data_mean + cut
    
    #creating an array of lower, higher and total outlier values
    outliers_lower = [x for x in df if x <lower]
    outliers_higher = [x for x in df if x >upper]
    outliers_total = [x for x in df if x <lower or x>upper]
    
    # array without outlier values
    outliers_removed = [x for x in df_num if x > lower and x < upper]
    
    print('Identified lowest outliers: %d' % len(outliers_lower)) # printing total number of values in lower cut of outliers
    print('Identified upper outliers: %d' % len(outliers_higher)) # printing total number of values in higher cut of outliers
    print('Total outlier observations: %d' % len(outliers_total)) # printing total number of values outliers of both sides
    print('Non-outlier observations: %d' % len(outliers_removed)) # printing total number of non outlier values
    print("Total percentual of Outliers: ", round((len(outliers_total) / len(outliers_removed) )*100, 4)) # Percentual of outliers in points
    
    return

# %% [markdown]
# ## Data shape

# %%
print('train_transaction shape is {}'.format(train_transaction.shape))
print('test_transaction shape is {}'.format(test_transaction.shape))
print('train_identity shape is {}'.format(train_identity.shape))
print('test_identity shape is {}'.format(test_identity.shape))
# Out:
# train_transaction shape is (590540, 393)
# test_transaction shape is (506691, 392)
# train_identity shape is (144233, 40)
# test_identity shape is (141907, 40)

# %%
print(train.shape)
print(test.shape)
# Out:
# (590540, 433)
# (506691, 432)

# %%
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## Missingness

# %%
def missing_data(data):
    missing = data.isnull().sum()
    percent = (data.isnull().sum()/data.isnull().count()*100)
    df_missing = pd.concat([missing, percent], axis=1, keys=['Total', 'Percent'])
    types = []
    for col in data.columns:
        dtype = str(data[col].dtype)
        types.append(dtype)
    df_missing['Types'] = types
    return(df_missing)

# %%
m_train = missing_data(train)
m_test = missing_data(test)
print(m_train[m_train['Percent'] >0].count()) #there are 414 columns with missing values
print(m_train[m_train['Percent'] == 0].count()) #there are 19 columns without missing values
# Out:
# Total      414
# Percent    414
# Types      414
# dtype: int64
# Total      19
# Percent    19
# Types      19
# dtype: int64

# %%
m_train[m_train['Percent']> 0].sort_values(by='Percent', ascending = False)[:15]
# Out:
#         Total    Percent    Types
# id_24  585793  99.196159  float64
# id_25  585408  99.130965  float64
# id_07  585385  99.127070  float64
# id_08  585385  99.127070  float64
# id_21  585381  99.126393  float64
# id_26  585377  99.125715  float64
# id_27  585371  99.124699   object
# id_23  585371  99.124699   object
# id_22  585371  99.124699  float64
# dist2  552913  93.628374  float16
# D7     551623  93.409930  float16
# id_18  545427  92.360721  float64
# D13    528588  89.509263  float16
# D14    528353  89.469469  float16
# D12    525823  89.041047  float16

# %%
plt.figure(figsize = (10, 7))
sns.barplot(y =m_train.index[:40], x = "Percent", data = m_train.sort_values(by= "Percent", ascending = False)[:40])
plt.title('40 features with highest missing percent')
# Out:
# Text(0.5, 1.0, '40 features with highest missing percent')

# %%
train['nulls1']= train.isna().sum(axis = 1)#the number of null values on each transactions. 
test['nulls1'] = test.isna().sum(axis =1 )

# %%
train.select_dtypes(include = 'object').columns
# Out:
# Index(['ProductCD', 'card4', 'card6', 'P_emaildomain', 'R_emaildomain', 'M1',
#        'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'id_12', 'id_15',
#        'id_16', 'id_23', 'id_27', 'id_28', 'id_29', 'id_30', 'id_31', 'id_33',
#        'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 'DeviceType',
#        'DeviceInfo'],
#       dtype='object')

# %%
categorical = ["ProductCD", "card1", "card2", "card3", "card4", "card5", "card6",
                        "addr1", "addr2", "P_emaildomain", "R_emaildomain", "M1", "M2", "M3", "M4", "M5",
                        "M6", "M7", "M8", "M9", "DeviceType", "DeviceInfo", "id_12", "id_13", "id_14",
                        "id_15", "id_16", "id_17", "id_18", "id_19", "id_20", "id_21", "id_22", "id_23",
                        "id_24", "id_25", "id_26", "id_27", "id_28", "id_29", "id_30", "id_31", "id_32", 
                        "id_33", "id_34", "id_35", "id_36", "id_37", "id_38"] #from info page

# %%
#
plt.hist(train['nulls1'], normed=True, bins=30, alpha=0.4, label='train')
plt.hist(test['nulls1'], normed=True, bins=30, alpha=0.4, label='test')
plt.xlabel('Number of features which are NaNs')
plt.legend()

# %% [markdown]
# ### What's the target distribution?

# %%
df_tar = pd.DataFrame(train.isFraud.value_counts())
df_tar['Percent'] = round((df_tar['isFraud'] / len(train))*100, 2) 
df_tar['Percent'].values
# Out:
# array([96.5,  3.5])

# %%
d = sns.countplot(x = 'isFraud', data = train)
d.set_title('Target distribution in train dataset', fontsize = 18)
d.set_xlabel('Is fraud?', fontsize = 15)
d.set_ylabel('Count', fontsize = 15)
for p in d.patches:
    height = p.get_height()
    d.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/len(train)*100),
            ha="center", fontsize=15)

# %% [markdown]
# There are 3.5% of Fraud transaction in our dataset. The rest of 96.5% is not fraud.

# %% [markdown]
# ## TransactionDT

# %% [markdown]
# Time delta from a given reference datetime, in seconds.

# %%
def plot_time(col, xlim1, xlim2):
    fig, ax  = plt.subplots(figsize = (8,5))
    time_pattern = plt.hist(col /  (3600*24), bins = 2000)
    plt.xlim(xlim1, xlim2)
    plt.xlabel('Days')
    plt.ylabel('Number of transaction')
    plt.ylim(0, 1000) #zoom in to see the pattern 
    
    plt.show()

# %%
plot_time(train['TransactionDT'], 55, 65)

# %% [markdown]
# We can see the the number of transactions vary over the time of a day and also over a week period. (pattern over the day is strong)

# %% [markdown]
# So we need to create functions to turn the values into days and hours to plot and see if there is correlation between the time of the transaction and the possibility that it is fraud

# %%
#input: df to manipulate, offset in days to shift the start and end of the days, 
#column name to encode
def day_encoder(df, offset = 0, colname = 'TransactionDT'):
    days = df[colname] / (3600*24)
    encode_days = np.floor(days - 1 + offset) % 7 #review
    return encode_days

def hour_encoder(df, colname = 'TransactionDT'):
    hours = train['TransactionDT'] / 3600
    encode_hours = np.floor(hours) % 24 #review
    return encode_hours

# %% [markdown]
# Use the offset parameter to change what we define as the start of the day.

# %% [markdown]
# ### add weekday and hours to train and test

# %%
#there is not a significant correlation on the day 
#of the week and whether a transaction is fraudulent. 

train['weekday'] = day_encoder(train, offset = 0.58)
test['weekday'] = day_encoder(test, offset=  0.58)
plt.plot(train.groupby('weekday').mean()['isFraud'])

plt.ylim(0, 0.04)
plt.xlabel('Encoded day')
plt.ylabel('Fraction of fraudulent transactions')
# Out:
# Text(0, 0.5, 'Fraction of fraudulent transactions')

# %%
test['weekday'].value_counts()
# Out:
# 1.0    81162
# 4.0    80033
# 5.0    73853
# 6.0    72675
# 0.0    70891
# 3.0    64297
# 2.0    63780
# Name: weekday, dtype: int64

# %%
train['weekday'].value_counts()
# Out:
# 1.0    98920
# 0.0    86311
# 4.0    86283
# 6.0    85434
# 5.0    83596
# 2.0    75438
# 3.0    74558
# Name: weekday, dtype: int64

# %%
train['hours'] = hour_encoder(train)
test['hours'] = hour_encoder(test)
plt.plot(train.groupby('hours').mean()['isFraud']) #mean of isfraud column grouped by hours

plt.xlabel('Encoded hour') 
plt.ylabel('Fraction of fradulent transactions')
# Out:
# Text(0, 0.5, 'Fraction of fradulent transactions')

# %% [markdown]
# we can see that it's highly correlated with the hours

# %%
#del train['weekday'], train['hours']

# %%
test['TransactionDT'].head(10)
# Out:
# TransactionID
# 3663549    18403224
# 3663550    18403263
# 3663551    18403310
# 3663552    18403310
# 3663553    18403317
# 3663554    18403323
# 3663555    18403350
# 3663556    18403387
# 3663557    18403405
# 3663558    18403416
# Name: TransactionDT, dtype: int64

# %%
train['TransactionDT'].plot(kind = 'hist', figsize = (15,8), 
                                      label = 'train', 
                                      bins = 50, 
                                      title = 'Train vs Test TransactionDT distribuion')
test['TransactionDT'].plot(kind = 'hist', label = 'test',  bins = 50)
plt.legend()
plt.show()

# %% [markdown]
# ## Transaction Amt

# %%
train.TransactionAmt.sample(10)
# Out:
# TransactionID
# 3240717     39.00
# 3014282    117.00
# 3272822    138.95
# 3134761     58.95
# 3149322     54.50
# 3424316     59.00
# 3444664    159.95
# 3430299     97.00
# 3241516    117.00
# 3433252    108.50
# Name: TransactionAmt, dtype: float64

# %%
train['TransactionAmt'].astype(float)
print("Transaction Amounts Quantiles:")
train['TransactionAmt'].quantile([.01, .025, .1, .25, .5, .75, .9, .975, .99])
# Out:
# Transaction Amounts Quantiles:
# 0.010       9.2440
# 0.025      14.5010
# 0.100      25.9500
# 0.250      43.3210
# 0.500      68.7690
# 0.750     125.0000
# 0.900     275.2930
# 0.975     648.3345
# 0.990    1104.0000
# Name: TransactionAmt, dtype: float64

# %%
plt.figure(figsize = (15, 12))
#plot before log transform
plt.subplot(221)
amt = sns.distplot(train[train['TransactionAmt'] < 600]['TransactionAmt'], 
                  kde = True, kde_kws={'linewidth': 2})
# this will draw a histogram and fit a kernel density estimate (KDE).

amt.set_title("Transaction Amount Distribution <= 1000", fontsize = 17)
amt.set_ylabel("Probability Density")

#plot after log transform
plt.subplot(223)
amt_log = np.log(train['TransactionAmt'])
amt2 = sns.distplot(amt_log, kde = True, kde_kws={'linewidth': 2})
amt2.set_title("Transaction amount (Log) distribution", fontsize = 17)
amt2.set_ylabel("Probability Density")
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# Difference from the probability is the probability density is the probability per unit on the x-axis. To convert to an actual probability, we need to find the area under the curve for a specific interval on the x-axis. Somewhat confusingly, because this is a probability density and not a probability, the y-axis can take values greater than one. The only requirement of the density plot is that the total area under the curve integrates to one.

# %% [markdown]
# ## What are the distribution of transaction amount for fraudulent and not fraudulent ones?

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,5))

time_val = train_transaction.loc[train_transaction['isFraud'] == 1]['TransactionAmt'].values

sns.distplot(time_val, ax=ax[0], color='r')
ax[0].set_title('Distribution of LOG TransactionAmt, isFraud=1', fontsize=18)
ax[1].set_xlim([min(np.log(time_val)), max(np.log(time_val))])

time_val = train_transaction.loc[train_transaction['isFraud'] == 0]['TransactionAmt'].values

sns.distplot(np.log(time_val), ax=ax[1], color='b')
ax[1].set_title('Distribution of LOG TransactionAmt, isFraud=0', fontsize=18)
ax[1].set_xlim([min(np.log(time_val)), max(np.log(time_val))])


plt.show()

# %% [markdown]
# ## Categorical Features:
#     1. Product CD
#     2. P_emaildomain, R_email_domain
#     3. card1- card6
#     4. M1-m9
#     5. device type, device info
#     6. id12 - id 38

# %%
train.select_dtypes(include = 'object').columns
# Out:
# Index(['ProductCD', 'card4', 'card6', 'P_emaildomain', 'R_emaildomain', 'M1',
#        'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'id_12', 'id_15',
#        'id_16', 'id_23', 'id_27', 'id_28', 'id_29', 'id_30', 'id_31', 'id_33',
#        'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 'DeviceType',
#        'DeviceInfo'],
#       dtype='object')

# %% [markdown]
# ## ProductCD

# %%
train.ProductCD.value_counts()
# Out:
# W    439670
# C     68519
# R     37699
# H     33024
# S     11628
# Name: ProductCD, dtype: int64

# %%
sns.countplot('ProductCD',  data = train)

# %% [markdown]
# very imbalanced towards W variable

# %% [markdown]
# ### Email domain

# %% [markdown]
# Group email domains by their enterprises - but binned values having drastically different rates of fraud. For example with the Microsoft bin, msn has a fraud rate around 2.2% while outlook is around 9.5%. so that's not the best ideas.

# %%
#  #whether each element in the datafraim is contained in values. 
# google = train['P_emaildomain'].isin(['gmail.com', 'gmail'])
# train.loc[google, 'P_emaildomain'] = 'google'
# yahoo = train['P_emaildomain'].isin(['yahoo.com', 'yahoo.com.mx', 'yahoo.fr',
#                                     'yahoo.de','yahoo.es', 'yahoo.co.uk',
#                                     'yahoo.co.jp'])
# microsoft  = train['P_emaildomain'].isin(['outlook.com', 'hotmail.com', 
#                                          'live.com.mx', 'live.com', 'msn.com ', 
#                                          'live.fr', 'hotmail.fr','hotmail.co.uk',
#                                           'hotmail.de', 'outlook.es', 'hotmail.es',
#                                           'outlook.es'])
# train.loc[microsoft, 'P_emaildomain'] = 'microsoft'
# train.loc[train.P_emaildomain.isin(train.P_emaildomain\
#                                          .value_counts()[train.P_emaildomain.value_counts() <= 400 ]\
#                                          .index), 'P_emaildomain'] = "Others"
# train.P_emaildomain.value_counts()
# train.P_emaildomain.fillna("None", inplace = True)
# train.P_emaildomain.value_counts()

# %%
train.P_emaildomain.value_counts().count()
# Out:
# 59

# %%
#P_emaildomain
fig, ax = plt.subplots(3,1, figsize = (7,18))

p = sns.countplot(y = 'P_emaildomain', data = train, order=train['P_emaildomain'].value_counts().sort_values(ascending=False).index[:20] , ax = ax[0])
p.set_title("P_emaildomain Count", fontsize=13)

p1 = sns.countplot(y = "P_emaildomain", ax = ax[1], data = train.loc[train['isFraud'] ==1], order=train.loc[train['isFraud']==1]['P_emaildomain'].value_counts().sort_values(ascending = False).index[:10])
ax[1].set_title('P_emaildomain isFraud = 1', fontsize=13)

p0 = sns.countplot(y = "P_emaildomain", data= train.loc[train['isFraud'] ==0], ax = ax[2], order=train.loc[train['isFraud']==0]['P_emaildomain'].value_counts().sort_values(ascending = False).index[:10])
ax[2].set_title("P_emaildomain isFraud = 0")
# Out:
# Text(0.5, 1.0, 'P_emaildomain isFraud = 0')

# %%
fig, ax = plt.subplots(3,1, figsize = (7,18))
p = sns.countplot(y = 'P_emaildomain', data = train, order=train['P_emaildomain'].value_counts().sort_values(ascending=False).index[:25] , ax = ax[0])
p.set_title("P_emaildomain Count", fontsize=13)

p1 = sns.countplot(y = "P_emaildomain", ax = ax[1], data = train.loc[train['isFraud'] ==1], order=train.loc[train['isFraud']==1]['P_emaildomain'].value_counts().sort_values(ascending = False).index[:25])
ax[1].set_title('P_emaildomain isFraud = 1', fontsize=13)

p0 = sns.countplot(y = "P_emaildomain", data= train.loc[train['isFraud'] ==0], ax = ax[2], order=train.loc[train['isFraud']==0]['P_emaildomain'].value_counts().sort_values(ascending = False).index[:25])
ax[2].set_title("P_emaildomain isFraud = 0")
# Out:
# Text(0.5, 1.0, 'P_emaildomain isFraud = 0')

# %%
# ##R_emaildomain
# google = train['R_emaildomain'].isin(['gmail.com', 'gmail'])
# train.loc[google, 'R_emaildomain'] = 'google'
# yahoo = train['R_emaildomain'].isin(['yahoo.com', 'yahoo.com.mx', 'yahoo.fr',
#                                     'yahoo.de','yahoo.es', 'yahoo.co.uk',
#                                     'yahoo.co.jp'])
# microsoft  = train['R_emaildomain'].isin(['outlook.com', 'hotmail.com', 
#                                          'live.com.mx', 'live.com', 'msn.com ', 
#                                          'live.fr', 'hotmail.fr','hotmail.co.uk',
#                                           'hotmail.de', 'outlook.es', 'hotmail.es',
#                                           'outlook.es'])
# train.loc[microsoft, 'R_emaildomain'] = 'microsoft'
# train.loc[train.R_emaildomain.isin(train.R_emaildomain\
#                                          .value_counts()[train.R_emaildomain.value_counts() <= 300 ]\
#                                          .index), 'R_emaildomain'] = "Others"
# train.R_emaildomain.value_counts()
# train.R_emaildomain.fillna("None", inplace = True)
# train.R_emaildomain.value_counts()

# %%
# fig, ax = plt.subplots(3,1, figsize = (9,18))
r = sns.countplot(y = 'R_emaildomain', data = train, order=train['R_emaildomain'].value_counts().sort_values(ascending=False).index , ax = ax[0])
r.set_title("R_emaildomain Count", fontsize=13)

r1 = sns.countplot(y = "R_emaildomain", ax = ax[1], data = train.loc[train['isFraud'] ==1], order=train.loc[train['isFraud']==1]['R_emaildomain'].value_counts().sort_values(ascending = False).index)
ax[1].set_title('R_emaildomain isFraud = 1', fontsize=13)

r0 = sns.countplot(y = "R_emaildomain", data= train.loc[train['isFraud'] ==0], ax = ax[2], order=train.loc[train['isFraud']==0]['R_emaildomain'].value_counts().sort_values(ascending = False).index)
ax[2].set_title("R_emaildomain isFraud = 0")
# Out:
# Text(0.5, 1.0, 'R_emaildomain isFraud = 0')

# %% [markdown]
# ## Device Type and Device Info

# %%
train.DeviceType.fillna('Null', inplace=True)

# %%
d = sns.countplot(x = "DeviceType", data = train)
d.set_title('DeviceType', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'DeviceType')

# %%
sns.countplot(x='DeviceType', hue='isFraud', data=train)
plt.title('DeviceType count by isFraud')
# Out:
# Text(0.5, 1.0, 'DeviceType count by isFraud')

# %%
a = train['DeviceType'] == 'Null'
a.value_counts()
449730 /len(train)
# Out:
# 0.7615572188166763

# %% [markdown]
# Device Info

# %%
print("Unique Devices = ",train_identity['DeviceInfo'].nunique())
train['DeviceInfo'].value_counts().head()
# Out:
# Unique Devices =  1786
# Windows        47722
# iOS Device     19782
# MacOS          12573
# Trident/7.0     7440
# rv:11.0         1901
# Name: DeviceInfo, dtype: int64

# %%
info_df = train.DeviceInfo.value_counts().to_frame()
train.groupby(by = "DeviceInfo").count()['isFraud']
# Out:
# DeviceInfo
# 0PAJ5                           1
# 0PJA2                           1
# 0PM92                           4
# 1016S                           1
# 2PQ93                           1
# 2PS64 Build/NRD90M              6
# 2PYB2                           4
# 2PZC5                           2
# 4003A                           1
# 4009F                           2
# 4013M Build/KOT49H             13
# 4027A Build/KOT49H              2
# 4034E                           1
# 4034G                           1
# 4047A Build/NRD90M              7
# 4047G Build/NRD90M             17
# 47418                           1
# 5010G Build/MRA58K             60
# 5010S Build/MRA58K             13
# 5011A Build/NRD90M             24
# 5012G Build/MRA58K             29
# 5015A Build/LMY47I             38
# 5017A                           2
# 5025G Build/LMY47I             38
# 5042A                           2
# 5044A                           1
# 5045I                           1
# ...

# %%
plt.figure(figsize = (10, 7))

sns.barplot(y = info_df.index[:20], x = "DeviceInfo", data = info_df.sort_values(by= "DeviceInfo", ascending = False)[:20])

# %%
fig, ax = plt.subplots( figsize = (15,10))
sns.countplot(y = "DeviceInfo", data = train.loc[train['isFraud'] ==1], order=train.loc[train['isFraud']==1]['DeviceInfo'].value_counts().sort_values(ascending = False).index[:15])
ax.set_title('DeviceInfo isFraud = 1', fontsize=13)
# Out:
# Text(0.5, 1.0, 'DeviceInfo isFraud = 1')

# %% [markdown]
# ## Models

# %%
del train_transaction, train_identity, test_transaction, test_identity

# %%
y_train = train['isFraud'].copy()

#drop target and fill NAs
X_train = train.drop('isFraud', axis = 1)
X_test = test.copy()
X_train = X_train.fillna(-999)
X_test = X_test.fillna(-999)
##Label Encoding

for f in X_train.columns:
    if X_train[f].dtype == 'object' or X_test[f].dtype == 'object':
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(X_train[f].values) + list(X_test[f].values))
        X_train[f] = lbl.transform(list(X_train[f].values))
        X_test[f] = lbl.transform(list(X_test[f].values))

# %%
clf = xgb.XGBClassifier(n_estimators = 500, 
                       n_jobs = 4, 
                       max_depth = 9, 
                       learning_rate = 0.05, 
                       sub_sample = 0.9, 
                       colsample_bytree = 0.9, 
                       missing = -999)
clf.fit(X_train, y_train)

# %%
sample_sub['isFraud'] = clf.predict_proba(X_test)[:,1]
sample_sub.to_csv('xgboost2.csv')
